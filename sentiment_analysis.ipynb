# %%
# Calculate the average sentiment score per broadcaster
avg_scores = df.groupby('Broadcaster')['Score'].mean().reset_index()

# Plot average sentiment score by broadcaster
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=avg_scores, x='Broadcaster', y='Score', palette='viridis')

# Add the score numbers above the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',  # rounded to two decimal places
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=12, color='black', 
                xytext=(0, 5),  # slight offset above the bar
                textcoords='offset points')

plt.title("Average Sentiment Score by Broadcaster")
plt.xlabel("Broadcaster")
plt.ylabel("Average Sentiment Score")
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/4_/3fkfmzxx4hvg5wfsm9hgrb6m0000gn/T/ipykernel_5858/3438989581.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=avg_scores, x='Broadcaster', y='Score', palette='viridis')

# %%
# Plot sentiment distribution per broadcaster
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='Broadcaster', hue='Sentiment', palette='Set2')

# Add the count numbers above the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=12, color='black', 
                xytext=(0, 5),  # slight offset above the bar
                textcoords='offset points')

plt.title("Sentiment by Broadcaster")
plt.xlabel("Broadcaster")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Sentiment score distribution (confidence scores)
plt.figure(figsize=(8, 6))
sns.histplot(df['Score'], kde=True, color='blue', bins=20)
plt.title("Sentiment Confidence Scores Distribution")
plt.xlabel("Sentiment Score (Confidence)")
plt.ylabel("Frequency")
plt.show()

# %%
# Plot the sentiment distribution (positive vs negative)
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='Sentiment', palette='Set2')

# Add the count numbers above the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=12, color='black', 
                xytext=(0, 5),  # slight offset above the bar
                textcoords='offset points')

plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
# Out:
# /var/folders/4_/3fkfmzxx4hvg5wfsm9hgrb6m0000gn/T/ipykernel_5858/417688709.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Sentiment', palette='Set2')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the sentiment analysis results CSV file
df = pd.read_csv('/Users/psylviana/Downloads/VideoAnalyse/YOLO-Video-Analysis/sentiment_analysis_results.csv')

# Show the first few rows of the data
df.head()
# Out:
#   Broadcaster                         Video Sentiment     Score
# 0         WDR  RPReplay_Final1741876051.txt  NEGATIVE  0.994920
# 1         WDR  RPReplay_Final1741874207.txt  POSITIVE  0.999394
# 2         WDR  RPReplay_Final1741875050.txt  NEGATIVE  0.994530
# 3         WDR  RPReplay_Final1741876170.txt  NEGATIVE  0.995374
# 4         WDR  RPReplay_Final1741875916.txt  NEGATIVE  0.968450
